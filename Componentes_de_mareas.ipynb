# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Para generar una señal cuya amplitud esté modulada:
#
# $$c(t) = A_c cos (𝜔_ct)$$ señal original (portadora)
#
# $$m(t) = A_m cos(𝜔_m t) $$ señal moduladora
#
# $$AM(t) = [A_c + m(t)] cos(𝜔_c t) $$ Señal de Amplitud Modulada

# %%
#Ejemplo de clase de modulación de amplitud
A_c = 1#float(input('Enter carrier amplitude: '))
f_c = 1/12#float(input('Enter carrier frquency: '))
A_m = 1#float(input('Enter message amplitude: '))
f_m = 1/(12*30)#float(input('Enter message frquency: '))
modulation_index = A_m/A_c#float(input('Enter modulation index: '))

# %%
#t = np.linspace(0,30,24*30)
t=np.arange(0,30*24,0.5)
carrier = A_c*np.cos(2*np.pi*f_c*t)
modulator = A_m*np.cos(2*np.pi*f_m*t)
product = A_c*(1+modulation_index*np.cos(2*np.pi*f_m*t))*np.cos(2*np.pi*f_c*t)

# %%
plt.subplot(3,1,1)
plt.title('Amplitude Modulation')
plt.plot(t/24,modulator,'g')
plt.ylabel('Amplitude')
plt.xlabel('Message signal')

plt.subplot(3,1,2)
plt.plot(t/24,carrier, 'r')
plt.ylabel('Amplitude')
plt.xlabel('Carrier signal')

plt.subplot(3,1,3)
plt.plot(product, color="purple")
plt.ylabel('Amplitude')
plt.xlabel('AM signal')

plt.subplots_adjust(hspace=1)
plt.rc('font', size=15)
fig = plt.gcf()
fig.set_size_inches(16, 9)

# %% [markdown]
# Trabajo Práctico 3
# Componentes armónicos de marea
#
# 1) En este ejercicio se analiza la onda resultante de las componentes armónicas de marea
# usando las amplitudes derivadas de la Teoria de Equilibrio. Utilizando el software
# que prefiera, calcule y grafique.
# a. Para un período de 30 días, calcule y grafique una onda de 1 m de amplitud
# con frecuencia de 28.9841 °/h (período de 12.42 h).

# %%
#ONDAS EJERCICIO 1
t=np.arange(0,24*30) # Eje temporal de un mes de datos horarios
M2=1*np.cos(np.deg2rad(28.9841*t))
S2=0.4652*np.cos(np.deg2rad(30*t))
N2=0.1915*np.cos(np.deg2rad(28.436*t))
K1=0.40*np.cos(np.deg2rad(15.043878*t+90))
O1=0.40*np.cos(np.deg2rad(13.94268*t))
L2=0.0383*np.cos(np.deg2rad(29.5241*t))
#sumas
sum1=M2+S2
sum2=sum1+N2
sum3=sum2+K1+O1
modl=M2+N2+L2
modl1=M2+N2
modl2=M2+L2
k1o1=K1+O1

# %%
fig,axs=plt.subplots(1,1,figsize=(30,4))
axs.plot(t/24,M2)
axs.plot(t/24,S2)
axs.plot(t/24,N2)
axs.plot(t/24,K1)
axs.plot(t/24,O1)
axs.set(title='M2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')
axs.legend(['M2','S2','N2','K1','O1'],bbox_to_anchor=[-.1, 1.15], loc='upper left')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,M2)
axs.set(title='M2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':') #es una pavada, para ver los colores

# %%
#criterio de rayleigh es necesario?
fig,axs=plt.subplots(1,1,figsize=(15,4))
axs.plot(t/24,M2)
axs.plot(t/24,S2)
axs.set(title='M2 y S2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')
axs.legend(['M2','S2'],bbox_to_anchor=[-.15, 1.15], loc='upper left')

# %%
#Ejercicio 1.b.
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,S2)
axs.set(title='S2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,N2)
axs.set(title='N2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')

# %%
#Ejercicio 1.b.
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,M2,':k')
axs.plot(t/24,sum1)
axs.set(title='Modulación de M2 por S2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')
axs.legend(['M2','M2 + S2'],bbox_to_anchor=[-.25, 1.15], loc='upper left')

# %%
#Ejercicio 1.c.
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,N2,':k')
axs.plot(t/24,sum1)
axs.set(title='Modulación M2 por S2 y N2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')
axs.legend(['N2','M2 + S2'],bbox_to_anchor=[-.25, 1.15], loc='upper left')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,sum2)
fig.suptitle('Resultante de componentes armónicas M2, S2 Y N2', x=.5)
axs.set(ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')
#title='Resultante de componentes armónicas M2, S2 Y N2', iba dentro de axs.set

# %%
#Ejercicio 1.d.
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,K1,'k')
axs.plot(t/24,O1,'g')
axs.plot(t/24,sum2)
fig.suptitle('Resultante de componentes armónicas M2, S2 Y N2, O1 y K1', x=.5)
axs.set(ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')
axs.legend(['K1','O1','M2 + S2 + N2'],bbox_to_anchor=[-.3, 1.15], loc='upper left')

# %%
#Ejercicio 1.d.
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,sum3)
fig.suptitle('Resultante de componentes armónicas M2, S2, N2, O1 y K1', x=.5)
axs.set(ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')

# %% [markdown]
# b. Para el mismo período, calcule y grafique una onda de 0.4652 m de amplitud
# con una frecuencia de 30°/h (período de 12 h). Obtenga la sumatoria de ambas
# ondas y grafíquela para los 30 días. Describa el efecto de la superposición.

# %%
otra=0.4652*np.cos(np.deg2rad(30*t))
suma=otra+M2

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,M2,':k')
axs.plot(t/24,suma)
axs.set(title='M2+Otra',ylabel='Altura (m)',xlabel='días')
axs.legend(['M2','M2 + otra'])
axs.grid(which='both',color='lightgrey',ls=':')

# %%
tt=np.arange(0,1000*24,0.5)
S2a=0.4652*np.cos(np.deg2rad(30*tt))
T2=0.0587*np.cos(np.deg2rad(29.9589*tt))
R2=0.0084*np.cos(np.deg2rad(30.0411*tt+180))
sum4=T2+R2+S2a

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(tt/24,T2)
axs.plot(tt/24,R2)
axs.set(title='M2+Otra',ylabel='Altura (m)',xlabel='días')
axs.legend(['S2','S2 Modulada'])
axs.grid(which='both',color='lightgrey',ls=':')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(tt/24,S2a)
axs.plot(tt/24,sum4)
axs.set(title='Resultante de componentes armónicas S2,T2 y R2 y gráfica de S2',ylabel='Altura (m)',xlabel='días')
axs.set_xlim(180, 185)
axs.legend(['S2','S2 + T2 + R2'],bbox_to_anchor=[-.25, 1.15], loc='upper left')
axs.grid(which='both',color='lightgrey',ls=':')

# %%
T2a=0.0587*np.cos(np.deg2rad(29.9589*t))
R2a=0.0084*np.cos(np.deg2rad(30.0411*t+180))
sum5=M2+T2a+R2a+S2
M2a=1*np.cos(np.deg2rad(28.9841*tt))
sum6=M2a+sum4
sum1p=M2a+S2a

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,M2)
axs.plot(t/24,sum5)
axs.plot(t/24,sum1)
axs.set(title='M2+Otra',ylabel='Altura (m)',xlabel='días')
axs.legend(['S2','S2 Modulada'])
axs.grid(which='both',color='lightgrey',ls=':')

# %%
#Intento de comparacion entre Suma de s2 con sus moduladoras  y la suma con m2
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(tt/24,sum6)
axs.plot(tt/24,sum4)
axs.set(title='Resultante S2, T2 y R2 y Resultante S2, T2, R2 y M2',ylabel='Altura (m)',xlabel='días')
axs.set_xlim(0, 730)
axs.legend(['S2+T2+R2+M2','S2+T2+R2'],bbox_to_anchor=[-.32, 1.15], loc='upper left')
axs.grid(which='both',color='lightgrey',ls=':')

# %%
(360/12.66)-28.9841
# Out:
# -0.5480810426540295

# %%
#de yapa, modulacion de M2 completa
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,modl)
axs.set(title='Modulación de M2 por S2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')
axs.legend(['M2','M2 + S2'],bbox_to_anchor=[-.25, 1.15], loc='upper left')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,modl1)
axs.set(title='Modulación de M2 por N2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,modl2)
axs.set(title='Modulación de M2 por S2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')
axs.legend(['M2','M2 + S2'],bbox_to_anchor=[-.25, 1.15], loc='upper left')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(t/24,k1o1)
axs.set(title='Resultante de componentes armónicas O1 y K1',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')

# %%
fig,axs=plt.subplots(1,1,figsize=(16,4))
axs.plot(t/24,K1)
axs.plot(t/24,O1)
axs.set(title='O1 y K1',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')
axs.legend(['K1','O1'],bbox_to_anchor=[-.15, 1.15], loc='upper left')

# %%
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(tt/24,T2)
axs.plot(tt/24,R2)
#axs.plot(tt/24,S2a)
axs.set(title='T2 y R2',ylabel='Altura (m)',xlabel='días')
axs.set_xlim(0,730)
axs.grid(which='both',color='lightgrey',ls=':')
axs.legend(['T2','R2'],bbox_to_anchor=[-.25, 1.15], loc='upper left')

# %%
#Ejercicio 1.b.
fig,axs=plt.subplots(1,1,figsize=(12,4))
axs.plot(tt/24,S2a)
axs.set_xlim(80, 85)
axs.set(title='S2',ylabel='Altura (m)',xlabel='días')
axs.grid(which='both',color='lightgrey',ls=':')
